# %% [markdown]
# # Subplots in Matplotlib

# %% [markdown]
# ## Loading data

# %%
from sklearn import datasets

dataset = datasets.load_iris()

features = dataset.data
target = dataset.target

features.shape, target.shape
# Out:
# ((150, 4), (150,))

# %% [markdown]
# General parameters of the graph for the whole notebook

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

#nice convenient little trick to flatten the axes, so it is easier to work with them
for i, axis in enumerate(axes.flat):
    axis.hist(features[:, i])
    axis.set_xlabel(dataset.feature_names[i])
    axis.set_ylabel('number of objects')
